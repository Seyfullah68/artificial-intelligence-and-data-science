# %%
# !pip install pandas_datareader
# !pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/14/03/3c854ca3e02eedf614abba4b2e177c469bf3af58207fa30d5098c5d652fe/yfinance-0.2.37-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/314.6 kB ? eta -:--:--
#      - -------------------------------------- 10.2/314.6 kB ? eta -:--:--
#      ---- -------------------------------- 41.0/314.6 kB 653.6 kB/s eta 0:00:01
#      ------------------- ------------------ 163.8/314.6 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 314.6/314.6 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
import pandas_datareader as pr
from pandas_datareader import data as pdr
import yfinance as yfin
import pandas as pd

# %%
yfin.pdr_override()
apple = pdr.get_data_yahoo('AAPL', start='2022-10-24', end='2022-12-23')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-24  147.190002  150.229996  146.000000  149.449997  148.184067
# 2022-10-25  150.089996  152.490005  149.360001  152.339996  151.049591
# 2022-10-26  150.960007  151.990005  148.039993  149.350006  148.084930
# 2022-10-27  148.070007  149.050003  144.130005  144.800003  143.573456
# 2022-10-28  148.199997  157.500000  147.820007  155.740005  154.420792
#
#                Volume
# Date
# 2022-10-24   75981900
# 2022-10-25   74732300
# 2022-10-26   88194300
# 2022-10-27  109180200
# 2022-10-28  164762400

# %%
apple.shape
# Out:
# (43, 6)

# %%
apple.plot();

# %%
apple.index
# Out:
# DatetimeIndex(['2022-10-24', '2022-10-25', '2022-10-26', '2022-10-27',
#                '2022-10-28', '2022-10-31', '2022-11-01', '2022-11-02',
#                '2022-11-03', '2022-11-04', '2022-11-07', '2022-11-08',
#                '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-14',
#                '2022-11-15', '2022-11-16', '2022-11-17', '2022-11-18',
#                '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25',
#                '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01',
#                '2022-12-02', '2022-12-05', '2022-12-06', '2022-12-07',
#                '2022-12-08', '2022-12-09', '2022-12-12', '2022-12-13',
#                '2022-12-14', '2022-12-15', '2022-12-16', '2022-12-19',
#                '2022-12-20', '2022-12-21', '2022-12-22'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
#eger tarihler tanımlı degilse tarih olarak tanımlamamız gerekir

# %%
apple.index=pd.DatetimeIndex(apple.index)

# %%
apple.plot()
#apple in hisse degeri grafigi
# Out:
# <Axes: xlabel='Date'>
